# %% [markdown]
# <a href="https://colab.research.google.com/github/Thmsantos/Api_de_temperatura/blob/main/exerc8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
raio = float(input("raio: "))

volume = (4 * ( 3.14 * (raio ** 3))) / 3

print ("volume = %4.1f"  % volume)
# Out:
# raio: 10
# volume = 4186.7
