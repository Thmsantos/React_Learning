# %% [markdown]
# <a href="https://colab.research.google.com/github/Thmsantos/Api_de_temperatura/blob/main/exerc1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = float(input("A = "))
b = float(input("B = "))
x = a + b 

print("%d + %f= %4.1f" %(a , b, x))
# Out:
# A = 30
# B = 45.7
# 30 + 45 = 75.7
