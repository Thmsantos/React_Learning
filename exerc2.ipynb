# %% [markdown]
# <a href="https://colab.research.google.com/github/Thmsantos/Api_de_temperatura/blob/main/exerc2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int (input("a: "))
b = int (input("b: "))

x = a * b

print("%d * %d = %d" %(a, b, x))
# Out:
# a: 20
# b: 3
# 20 * 3 = 60
